# %% [markdown]
# # Adetutu B Data Cleaning Project

# %% [markdown]
# # C4 Quality Check

# %%
pip install matplotlib
# Out:
# Note: you may need to restart the kernel to use updated packages.Requirement already satisfied: matplotlib in c:\anacondapython\lib\site-packages (3.8.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\anacondapython\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\anacondapython\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\anacondapython\lib\site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\anacondapython\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy<2,>=1.21 in c:\anacondapython\lib\site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\anacondapython\lib\site-packages (from matplotlib) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\anacondapython\lib\site-packages (from matplotlib) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\anacondapython\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\anacondapython\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\anacondapython\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
#Importing python libraries
import pandas as pd
from pandas.api.types import CategoricalDtype
import numpy as np
from matplotlib import pyplot as plt
from sklearn.decomposition import PCA
import seaborn as sns
from scipy import stats
# %matplotlib inline

#Loading the medical_raw_data.csv without the unnamed column
df = pd.read_csv('./medical_raw_data.csv', index_col = 0)

#Viewing the database information (data types, value amounts, etc)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10000 entries, 1 to 10000
# Data columns (total 52 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   CaseOrder           10000 non-null  int64
#  1   Customer_id         10000 non-null  object
#  2   Interaction         10000 non-null  object
#  3   UID                 10000 non-null  object
#  4   City                10000 non-null  object
#  5   State               10000 non-null  object
#  6   County              10000 non-null  object
#  7   Zip                 10000 non-null  int64
#  8   Lat                 10000 non-null  float64
#  9   Lng                 10000 non-null  float64
#  10  Population          10000 non-null  int64
#  11  Area                10000 non-null  object
#  12  Timezone            10000 non-null  object
#  13  Job                 10000 non-null  object
#  14  Children            7412 non-null   float64
#  15  Age                 7586 non-null   float64
#  16  Education           10000 non-null  object
#  17  Employment          10000 non-null  object
#  18  Income              7536 non-null   float64
#  19  Marital             10000 non-null  object
#  20  Gender              10000 non-null  object
#  21  ReAdmis             10000 non-null  object
#  22  VitD_levels         10000 non-null  float64
#  23  Doc_visits          10000 non-null  int64
#  24  Full_meals_eaten    10000 non-null  int64
#  25  VitD_supp           10000 non-null  int64
#  26  Soft_drink          7533 non-null   object
#  27  Initial_admin       10000 non-null  object
#  28  HighBlood           10000 non-null  object
#  29  Stroke              10000 non-null  object
#  30  Complication_risk   10000 non-null  object
#  31  Overweight          9018 non-null   float64
#  32  Arthritis           10000 non-null  object
#  33  Diabetes            10000 non-null  object
#  34  Hyperlipidemia      10000 non-null  object
#  35  BackPain            10000 non-null  object
#  36  Anxiety             9016 non-null   float64
#  37  Allergic_rhinitis   10000 non-null  object
#  38  Reflux_esophagitis  10000 non-null  object
#  39  Asthma              10000 non-null  object
#  40  Services            10000 non-null  object
#  41  Initial_days        8944 non-null   float64
#  42  TotalCharge         10000 non-null  float64
#  43  Additional_charges  10000 non-null  float64
#  44  Item1               10000 non-null  int64
#  45  Item2               10000 non-null  int64
#  46  Item3               10000 non-null  int64
#  47  Item4               10000 non-null  int64
#  48  Item5               10000 non-null  int64
#  49  Item6               10000 non-null  int64
#  50  Item7               10000 non-null  int64
#  51  Item8               10000 non-null  int64
# dtypes: float64(11), int64(14), object(27)
# memory usage: 4.0+ MB

# %%
#Checking for duplicates/making sure the unnamed column is not accounted as a duplicate of the placeholder (CaseOrder) column
print (df[df.duplicated()])
# Out:
# Empty DataFrame
# Columns: [CaseOrder, Customer_id, Interaction, UID, City, State, County, Zip, Lat, Lng, Population, Area, Timezone, Job, Children, Age, Education, Employment, Income, Marital, Gender, ReAdmis, VitD_levels, Doc_visits, Full_meals_eaten, VitD_supp, Soft_drink, Initial_admin, HighBlood, Stroke, Complication_risk, Overweight, Arthritis, Diabetes, Hyperlipidemia, BackPain, Anxiety, Allergic_rhinitis, Reflux_esophagitis, Asthma, Services, Initial_days, TotalCharge, Additional_charges, Item1, Item2, Item3, Item4, Item5, Item6, Item7, Item8]
# Index: []
#
# [0 rows x 52 columns]

# %%
#Visually inspecting the data frame to check for anomolies
pd.set_option("display.max_columns", None)
df
# Out:
#        CaseOrder Customer_id                           Interaction  \
# 1              1     C412403  8cd49b13-f45a-4b47-a2bd-173ffa932c2f
# 2              2     Z919181  d2450b70-0337-4406-bdbb-bc1037f1734c
# 3              3     F995323  a2057123-abf5-4a2c-abad-8ffe33512562
# 4              4     A879973  1dec528d-eb34-4079-adce-0d7a40e82205
# 5              5     C544523  5885f56b-d6da-43a3-8760-83583af94266
# ...          ...         ...                                   ...
# 9996        9996     B863060  a25b594d-0328-486f-a9b9-0567eb0f9723
# 9997        9997     P712040  70711574-f7b1-4a17-b15f-48c54564b70f
# 9998        9998     R778890  1d79569d-8e0f-4180-a207-d67ee4527d26
# 9999        9999     E344109  f5a68e69-2a60-409b-a92f-ac0847b27db0
# 10000      10000     I569847  bc482c02-f8c9-4423-99de-3db5e62a18d5
#
#                                     UID          City State        County  \
# 1      3a83ddb66e2ae73798bdf1d705dc0932           Eva    AL        Morgan
# 2      176354c5eef714957d486009feabf195      Marianna    FL       Jackson
# 3      e19a0fa00aeda885b8a436757e889bc9   Sioux Falls    SD     Minnehaha
# 4      cd17d7b6d152cb6f23957346d11c3f07  New Richland    MN        Waseca
# 5      d2f0425877b10ed6bb381f3e2579424a    West Point    VA  King William
# ...                                 ...           ...   ...           ...
# 9996   39184dc28cc038871912ccc4500049e5       Norlina    NC        Warren
# 9997   3cd124ccd43147404292e883bf9ec55c        Milmay    NJ      Atlantic
# 9998   41b770aeee97a5b9e7f69c906a8119d7     Southside    TN    Montgomery
# 9999   2bb491ef5b1beb1fed758cc6885c167a         Quinn    SD    Pennington
# 10000  95663a202338000abdf7e09311c2a8a1    Coraopolis    PA     Allegheny
#
#          Zip       Lat        Lng  Population      Area          Timezone  \
# 1      35621  34.34960  -86.72508        2951  Suburban   America/Chicago
# 2      32446  30.84513  -85.22907       11303     Urban   America/Chicago
# 3      57110  43.54321  -96.63772       17125  Suburban   America/Chicago
# 4      56072  43.89744  -93.51479        2162  Suburban   America/Chicago
# 5      23181  37.59894  -76.88958        5287     Rural  America/New_York
# ...      ...       ...        ...         ...       ...               ...
# 9996   27563  36.42886  -78.23716        4762     Urban  America/New_York
# 9997    8340  39.43609  -74.87302        1251     Urban  America/New_York
# 9998   37171  36.36655  -87.29988         532     Rural   America/Chicago
# 9999   57775  44.10354 -102.01593         271     Rural    America/Denver
# 10000  15108  40.49998  -80.19959       41524     Urban  America/New_York
#
#                                         Job  Children   Age  \
# 1          Psychologist, sport and exercise       1.0  53.0
# 2              Community development worker       3.0  51.0
# 3                   Chief Executive Officer       3.0  53.0
# 4                       Early years teacher       0.0  78.0
# 5               Health promotion specialist       NaN  22.0
# ...                                     ...       ...   ...
# 9996                 Programmer, multimedia       NaN  25.0
# 9997          Restaurant manager, fast food       4.0  87.0
# 9998             Psychologist, occupational       3.0   NaN
# 9999   Outdoor activities/education manager       3.0  43.0
# 10000            Sports development officer       8.0   NaN
#
#                                       Education Employment    Income  \
# 1                Some College, Less than 1 Year  Full Time  86575.93
# 2      Some College, 1 or More Years, No Degree  Full Time  46805.99
# 3      Some College, 1 or More Years, No Degree    Retired  14370.14
# 4                 GED or Alternative Credential    Retired  39741.49
# 5                   Regular High School Diploma  Full Time   1209.56
# ...                                         ...        ...       ...
# 9996                          Bachelor's Degree    Student  45967.61
# 9997                Regular High School Diploma  Full Time  14983.02
# 9998                Regular High School Diploma  Full Time  65917.81
# 9999                          Bachelor's Degree  Full Time  29702.32
# 10000       9th Grade to 12th Grade, No Diploma  Full Time  62682.63
#
#          Marital  Gender ReAdmis  VitD_levels  Doc_visits  Full_meals_eaten  \
# 1       Divorced    Male      No    17.802330           6                 0
# 2        Married  Female      No    18.994640           4                 2
# 3        Widowed  Female      No    17.415889           4                 1
# 4        Married    Male      No    17.420079           4                 1
# 5        Widowed  Female      No    16.870524           5                 0
# ...          ...     ...     ...          ...         ...               ...
# 9996     Widowed    Male      No    16.481612           4                 2
# 9997     Widowed    Male     Yes    18.451601           5                 0
# 9998   Separated  Female     Yes    15.752751           4                 2
# 9999    Divorced    Male     Yes    21.956305           5                 2
# 10000  Separated  Female     Yes    20.421883           5                 0
#
#        VitD_supp Soft_drink          Initial_admin HighBlood Stroke  \
# 1              0        NaN    Emergency Admission       Yes     No
# 2              1         No    Emergency Admission       Yes     No
# 3              0         No     Elective Admission       Yes     No
# 4              0         No     Elective Admission        No    Yes
# 5              2        Yes     Elective Admission        No     No
# ...          ...        ...                    ...       ...    ...
# 9996           1         No    Emergency Admission       Yes     No
# 9997           0         No     Elective Admission       Yes     No
# 9998           0        Yes     Elective Admission       Yes     No
# 9999           1         No    Emergency Admission        No     No
# 10000          1         No  Observation Admission        No     No
#
#       Complication_risk  Overweight Arthritis Diabetes Hyperlipidemia  \
# 1                Medium         0.0       Yes      Yes             No
# 2                  High         1.0        No       No             No
# 3                Medium         1.0        No      Yes             No
# 4                Medium         0.0       Yes       No             No
# 5                   Low         0.0        No       No            Yes
# ...                 ...         ...       ...      ...            ...
# 9996             Medium         NaN        No       No             No
# 9997             Medium         1.0       Yes      Yes             No
# 9998               High         1.0        No       No             No
# 9999             Medium         1.0        No       No             No
# 10000               Low         1.0       Yes       No            Yes
#
#       BackPain  Anxiety Allergic_rhinitis Reflux_esophagitis Asthma  \
# 1          Yes      1.0               Yes                 No    Yes
# 2           No      NaN                No                Yes     No
# 3           No      NaN                No                 No     No
# 4           No      NaN                No                Yes    Yes
# 5           No      0.0               Yes                 No     No
# ...        ...      ...               ...                ...    ...
# 9996        No      1.0                No                Yes     No
# 9997        No      0.0                No                 No    Yes
# 9998        No      1.0               Yes                 No     No
# 9999       Yes      0.0                No                 No     No
# 10000       No      0.0               Yes                 No     No
#
#           Services  Initial_days  TotalCharge  Additional_charges  Item1  \
# 1       Blood Work     10.585770  3191.048774        17939.403420      3
# 2      Intravenous     15.129562  4214.905346        17612.998120      3
# 3       Blood Work      4.772177  2177.586768        17505.192460      2
# 4       Blood Work      1.714879  2465.118965        12993.437350      3
# 5          CT Scan      1.254807  1885.655137         3716.525786      2
# ...            ...           ...          ...                 ...    ...
# 9996   Intravenous     51.561217  6651.241294         8927.642189      3
# 9997       CT Scan     68.668237  7851.522660        28507.147340      3
# 9998   Intravenous           NaN  7725.953391        15281.214660      3
# 9999    Blood Work     63.356903  8462.831883         7781.678412      5
# 10000   Blood Work     70.850592  8700.856021        11643.189930      4
#
#        Item2  Item3  Item4  Item5  Item6  Item7  Item8
# 1          3      2      2      4      3      3      4
# 2          4      3      4      4      4      3      3
# 3          4      4      4      3      4      3      3
# 4          5      5      3      4      5      5      5
# 5          1      3      3      5      3      4      3
# ...      ...    ...    ...    ...    ...    ...    ...
# 9996       2      2      3      4      3      4      2
# 9997       3      4      2      5      3      4      4
# 9998       3      3      4      4      2      3      2
# 9999       5      3      4      4      3      4      3
# 10000      3      3      2      3      6      4      3
#
# [10000 rows x 52 columns]

# %%
#Verifying the uniqueness of the placeholder variable (should return a result of 10000)
df.CaseOrder.value_counts().count()
# Out:
# 10000

# %%
#Verifying the uniqueness of the Customer_id column (should return a result of 10000)
df.Customer_id.value_counts().count()
# Out:
# 10000

# %%
#Verifying the uniqueness of the Interaction column (should return a result of 10000)
df.Interaction.value_counts().count()
# Out:
# 10000

# %%
#Verifying the uniqueness of the UID column (should return a result of 10000)
df.UID.value_counts().count()
# Out:
# 10000

# %%
#Verifying if the column can be classified as a categorical data type
df.Area.value_counts()
# Out:
# Area
# Rural       3369
# Suburban    3328
# Urban       3303
# Name: count, dtype: int64

# %%
#Verifying if the column can be classified as a categorical data type
df.Timezone.value_counts()
# Out:
# Timezone
# America/New_York                  3889
# America/Chicago                   3771
# America/Los_Angeles                937
# America/Denver                     612
# America/Detroit                    262
# America/Indiana/Indianapolis       151
# America/Phoenix                    100
# America/Boise                       86
# America/Anchorage                   50
# America/Puerto_Rico                 43
# Pacific/Honolulu                    34
# America/Menominee                   14
# America/Nome                        12
# America/Indiana/Vincennes            8
# America/Kentucky/Louisville          6
# America/Sitka                        6
# America/Toronto                      5
# America/Indiana/Marengo              3
# America/Indiana/Tell_City            3
# America/North_Dakota/Beulah          2
# America/Yakutat                      1
# America/Indiana/Winamac              1
# America/Indiana/Knox                 1
# America/North_Dakota/New_Salem       1
# America/Indiana/Vevay                1
# America/Adak                         1
# Name: count, dtype: int64

# %%
#Verifying if the column can be classified as a categorical data type
df.Education.value_counts()
# Out:
# Education
# Regular High School Diploma                 2444
# Bachelor's Degree                           1724
# Some College, 1 or More Years, No Degree    1484
# 9th Grade to 12th Grade, No Diploma          832
# Associate's Degree                           797
# Master's Degree                              701
# Some College, Less than 1 Year               642
# Nursery School to 8th Grade                  552
# GED or Alternative Credential                389
# Professional School Degree                   208
# No Schooling Completed                       133
# Doctorate Degree                              94
# Name: count, dtype: int64

# %%
#Verifying if the column can be classified as a categorical data type
df.Employment.value_counts()
# Out:
# Employment
# Full Time     6029
# Student       1017
# Part Time      991
# Unemployed     983
# Retired        980
# Name: count, dtype: int64

# %%
#Verifying if the column can be classified as a categorical data type
df.Marital.value_counts()
# Out:
# Marital
# Widowed          2045
# Married          2023
# Separated        1987
# Never Married    1984
# Divorced         1961
# Name: count, dtype: int64

# %%
#Verifying if the column can be classified as a categorical data type
df.Gender.value_counts()
# Out:
# Gender
# Female                  5018
# Male                    4768
# Prefer not to answer     214
# Name: count, dtype: int64

# %%
#Verifying if the column can be classified as a categorical data type
df.Initial_admin.value_counts()
# Out:
# Initial_admin
# Emergency Admission      5060
# Elective Admission       2504
# Observation Admission    2436
# Name: count, dtype: int64

# %%
#Verifying if the column can be classified as a categorical data type
df.Complication_risk.value_counts()
# Out:
# Complication_risk
# Medium    4517
# High      3358
# Low       2125
# Name: count, dtype: int64

# %%
#Verifying if the column can be classified as a categorical data type
df.Services.value_counts()
# Out:
# Services
# Blood Work     5265
# Intravenous    3130
# CT Scan        1225
# MRI             380
# Name: count, dtype: int64

# %%
#Verifying if the survey data can be classified as an ordinal categorical data type
df.Item1.value_counts()
# Out:
# Item1
# 4    3455
# 3    3404
# 5    1377
# 2    1315
# 6     225
# 1     213
# 7      10
# 8       1
# Name: count, dtype: int64

# %%
#Verifying if the survey data can be classified as an ordinal categorical data type
df.Item2.value_counts()
# Out:
# Item2
# 3    3439
# 4    3351
# 5    1421
# 2    1360
# 1     213
# 6     204
# 7      12
# Name: count, dtype: int64

# %%
#Verifying if the survey data can be classified as an ordinal categorical data type
df.Item3.value_counts()
# Out:
# Item3
# 4    3464
# 3    3379
# 5    1358
# 2    1356
# 6     220
# 1     211
# 7      11
# 8       1
# Name: count, dtype: int64

# %%
#Verifying if the survey data can be classified as an ordinal categorical data type
df.Item4.value_counts()
# Out:
# Item4
# 3    3422
# 4    3394
# 5    1388
# 2    1346
# 6     231
# 1     207
# 7      12
# Name: count, dtype: int64

# %%
#Verifying if the survey data can be classified as an ordinal categorical data type
df.Item5.value_counts()
# Out:
# Item5
# 4    3446
# 3    3423
# 2    1380
# 5    1308
# 6     219
# 1     211
# 7      13
# Name: count, dtype: int64

# %%
#Verifying if the survey data can be classified as an ordinal categorical data type
df.Item6.value_counts()
# Out:
# Item6
# 4    3464
# 3    3371
# 5    1403
# 2    1319
# 6     220
# 1     213
# 7      10
# Name: count, dtype: int64

# %%
#Verifying if the survey data can be classified as an ordinal categorical data type
df.Item7.value_counts()
# Out:
# Item7
# 4    3487
# 3    3456
# 2    1345
# 5    1274
# 1     215
# 6     212
# 7      11
# Name: count, dtype: int64

# %%
#Verifying if the survey data can be classified as an ordinal categorical data type
df.Item8.value_counts()
# Out:
# Item8
# 3    3401
# 4    3337
# 5    1429
# 2    1391
# 6     221
# 1     209
# 7      12
# Name: count, dtype: int64

# %%
#Checking the total amount of null values present in the dataset
df.isnull().sum()
# Out:
# CaseOrder                0
# Customer_id              0
# Interaction              0
# UID                      0
# City                     0
# State                    0
# County                   0
# Zip                      0
# Lat                      0
# Lng                      0
# Population               0
# Area                     0
# Timezone                 0
# Job                      0
# Children              2588
# Age                   2414
# Education                0
# Employment               0
# Income                2464
# Marital                  0
# Gender                   0
# ReAdmis                  0
# VitD_levels              0
# Doc_visits               0
# Full_meals_eaten         0
# VitD_supp                0
# Soft_drink            2467
# Initial_admin            0
# HighBlood                0
# Stroke                   0
# Complication_risk        0
# Overweight             982
# Arthritis                0
# Diabetes                 0
# Hyperlipidemia           0
# BackPain                 0
# Anxiety                984
# Allergic_rhinitis        0
# Reflux_esophagitis       0
# Asthma                   0
# Services                 0
# Initial_days          1056
# TotalCharge              0
# Additional_charges       0
# Item1                    0
# Item2                    0
# Item3                    0
# Item4                    0
# Item5                    0
# Item6                    0
# Item7                    0
# Item8                    0
# dtype: int64

# %%
#Stats for Detecing Outliers
with pd.option_context('display.max_columns', 40):
    print(df.describe(include = [np.number]))
    pd.reset_option('display.max_columns')
# Out:
#          CaseOrder           Zip           Lat           Lng     Population  \
# count  10000.00000  10000.000000  10000.000000  10000.000000   10000.000000
# mean    5000.50000  50159.323900     38.751099    -91.243080    9965.253800
# std     2886.89568  27469.588208      5.403085     15.205998   14824.758614
# min        1.00000    610.000000     17.967190   -174.209690       0.000000
# 25%     2500.75000  27592.000000     35.255120    -97.352982     694.750000
# 50%     5000.50000  50207.000000     39.419355    -88.397230    2769.000000
# 75%     7500.25000  72411.750000     42.044175    -80.438050   13945.000000
# max    10000.00000  99929.000000     70.560990    -65.290170  122814.000000
#
#           Children          Age         Income   VitD_levels    Doc_visits  \
# count  7412.000000  7586.000000    7536.000000  10000.000000  10000.000000
# mean      2.098219    53.295676   40484.438268     19.412675      5.012200
# std       2.155427    20.659182   28664.861050      6.723277      1.045734
# min       0.000000    18.000000     154.080000      9.519012      1.000000
# 25%       0.000000    35.000000   19450.792500     16.513171      4.000000
# 50%       1.000000    53.000000   33942.280000     18.080560      5.000000
# 75%       3.000000    71.000000   54075.235000     19.789740      6.000000
# max      10.000000    89.000000  207249.130000     53.019124      9.000000
#
#        Full_meals_eaten     VitD_supp   Overweight      Anxiety  Initial_days  \
# count      10000.000000  10000.000000  9018.000000  9016.000000   8944.000000
# mean           1.001400      0.398900     0.709137     0.322316     34.432082
# std            1.008117      0.628505     0.454186     0.467389     26.287050
# min            0.000000      0.000000     0.000000     0.000000      1.001981
# 25%            0.000000      0.000000     0.000000     0.000000      7.911709
# 50%            1.000000      0.000000     1.000000     0.000000     34.446941
# 75%            2.000000      1.000000     1.000000     1.000000     61.124654
# max            7.000000      5.000000     1.000000     1.000000     71.981486
#
#         TotalCharge  Additional_charges         Item1         Item2  \
# count  10000.000000        10000.000000  10000.000000  10000.000000
# mean    5891.538261        12934.528586      3.518800      3.506700
# std     3377.558136         6542.601544      1.031966      1.034825
# min     1256.751699         3125.702716      1.000000      1.000000
# 25%     3253.239465         7986.487642      3.000000      3.000000
# 50%     5852.250564        11573.979365      4.000000      3.000000
# 75%     7614.989701        15626.491033      4.000000      4.000000
# max    21524.224210        30566.073130      8.000000      7.000000
#
#               Item3         Item4         Item5         Item6         Item7  \
# count  10000.000000  10000.000000  10000.000000  10000.000000  10000.000000
# mean       3.511100      3.515100      3.496900      3.522500      3.494000
# std        1.032755      1.036282      1.030192      1.032376      1.021405
# min        1.000000      1.000000      1.000000      1.000000      1.000000
# 25%        3.000000      3.000000      3.000000      3.000000      3.000000
# 50%        4.000000      4.000000      3.000000      4.000000      3.000000
# 75%        4.000000      4.000000      4.000000      4.000000      4.000000
# max        8.000000      7.000000      7.000000      7.000000      7.000000
#
#               Item8
# count  10000.000000
# mean       3.509700
# std        1.042312
# min        1.000000
# 25%        3.000000
# 50%        3.000000
# 75%        4.000000
# max        7.000000

# %%
#Using histograms to visualize outliers
df.hist(figsize = (18, 30));

# %% [markdown]
# # D4 Code Mitigation

# %%
#Filling column blanks and NaNs with the value 0
df.Children.fillna(0, inplace=True)
df.Overweight.fillna(0, inplace=True)
df.Anxiety.fillna(0, inplace=True)
df.Initial_days.fillna(0, inplace=True)

#Changing column types from float to boolean
df['Overweight'] = df['Overweight'].astype('bool')
df['Anxiety'] = df['Anxiety'].astype('bool')

#Changing column types from float to integer
df['Children'] = df['Children'].astype('int64')
df['Initial_days'] = df['Initial_days'].astype('int64')

# %%
#Filling column NAs with the 'No'
df['Soft_drink'].fillna('No', inplace=True)
#Changing column type from string to boolean
df['Soft_drink'] = df['Soft_drink'].astype('bool')

# %%
#Finding the median age value and filling the blanks with it
median_age = round(df['Age'].median())
df['Age'].fillna(median_age, inplace=True)
#Changing column type from float to integer
df['Age'] = df['Age'].astype('Int64')

# %%
#Finding the median income value and filling the blanks with it
median_income = round(df['Income'].median())
df['Income'].fillna(median_income, inplace=True)

# %%
#Confirming all missing values were replaced
df.isnull().sum()
# Out:
# CaseOrder             0
# Customer_id           0
# Interaction           0
# UID                   0
# City                  0
# State                 0
# County                0
# Zip                   0
# Lat                   0
# Lng                   0
# Population            0
# Area                  0
# Timezone              0
# Job                   0
# Children              0
# Age                   0
# Education             0
# Employment            0
# Income                0
# Marital               0
# Gender                0
# ReAdmis               0
# VitD_levels           0
# Doc_visits            0
# Full_meals_eaten      0
# VitD_supp             0
# Soft_drink            0
# Initial_admin         0
# HighBlood             0
# Stroke                0
# Complication_risk     0
# Overweight            0
# Arthritis             0
# Diabetes              0
# Hyperlipidemia        0
# BackPain              0
# Anxiety               0
# Allergic_rhinitis     0
# Reflux_esophagitis    0
# Asthma                0
# Services              0
# Initial_days          0
# TotalCharge           0
# Additional_charges    0
# Item1                 0
# Item2                 0
# Item3                 0
# Item4                 0
# Item5                 0
# Item6                 0
# Item7                 0
# Item8                 0
# dtype: int64

# %%
#Changing column types from string to boolean
df['ReAdmis'] = df['ReAdmis'].astype('bool')
df['HighBlood'] = df['HighBlood'].astype('bool')
df['Stroke'] = df['Stroke'].astype('bool')
df['Arthritis'] = df['Arthritis'].astype('bool')
df['Diabetes'] = df['Diabetes'].astype('bool')
df['Hyperlipidemia'] = df['Hyperlipidemia'].astype('bool')
df['BackPain'] = df['BackPain'].astype('bool')
df['Allergic_rhinitis'] = df['Allergic_rhinitis'].astype('bool')
df['Reflux_esophagitis'] = df['Reflux_esophagitis'].astype('bool')
df['Asthma'] = df['Asthma'].astype('bool')

# %%
#Changing column type from integer to string and restoring leading 0's
df['Zip'] = df['Zip'].astype('str').str.zfill(5)

# %%
#Changing column types from string to category
df['Area'] = df['Area'].astype('category')
df['Education'] = df['Education'].astype('category')
df['Employment'] = df['Employment'].astype('category')
df['Marital'] = df['Marital'].astype('category')
df['Initial_admin'] = df['Initial_admin'].astype('category')
df['Complication_risk'] = df['Complication_risk'].astype('category')
df['Services'] = df['Services'].astype('category')

#Replacing response options to reflect the data dictionary
df.Gender.replace({
    'Prefer not to answer': 'Non-Binary'
}, inplace=True)
#Changing column type from string to category
df['Gender'] = df['Gender'].astype('category')

# %%
#Adjusting column decimal places from 6 to 2 places
df['TotalCharge'] = df.TotalCharge.round(2)
df['Additional_charges'] = df.Additional_charges.round(2)

#Standardizing the column to properly reflect time-zone values [In-text citation: (Indiana Destination Development Corporation, n.d.)]
df.Timezone.replace({
    #US Central Time
    'America/Chicago': 'US/CT',
    'America/North_Dakota/Beulah': 'US/CT',
    'America/North_Dakota/New_Salem': 'US/CT',
    'America/Menominee': 'US/CT',
    'America/Indiana/Tell_City': 'US/CT',
    'America/Indiana/Knox': 'US/CT',
    #US Eastern Time
    'America/New_York': 'US/ET',
    'America/Detroit': 'US/ET',
    'America/Toronto': 'US/ET',
    'America/Kentucky/Louisville': 'US/ET',
    'America/Indiana/Marengo': 'US/ET',
    'America/Indiana/Winamac': 'US/ET',
    'America/Indiana/Indianapolis': 'US/ET',
    'America/Indiana/Vincennes': 'US/ET',
    'America/Indiana/Vevay': 'US/ET',
    #US Alaska Time
    'America/Anchorage': 'US/AKDT',
    'America/Nome': 'US/AKDT',
    'America/Sitka': 'US/AKDT',
    'America/Yakutat': 'US/AKDT',
    #US Pacific Time
    'America/Los_Angeles': 'US/PT',
    #US Mountain/Mountain Standard Time
    'America/Boise': 'US/MT',
    'America/Denver': 'US/MT',
    'America/Phoenix': 'US/MST',
    #US Hawaii Standard/Hawaii-Aleutian Time
    'Pacific/Honolulu': 'US/HST',
    'America/Adak': 'US/HDT',
    #US Atlantic Time
    'America/Puerto_Rico': 'US/AST'
}, inplace=True)

#Changing column type from string to category
df['Timezone'] = df['Timezone'].astype('category')

# %%
#Set up survey response columns to reflect an ordinal categorical datatype
survey_rankings = CategoricalDtype(categories=['1', '2', '3', '4', '5', '6', '7', '8'], ordered=True)

#Mapping the integer as string, then changing column types to ordinal categorical (allowing the data to be transformed to a string before casting the columns will mitigate error messages when attempting to categorize) 
df['Item1'] = df['Item1'].map(str)
df['Item1'] = df['Item1'].astype(survey_rankings)
df['Item2'] = df['Item2'].map(str)
df['Item2'] = df['Item2'].astype(survey_rankings)
df['Item3'] = df['Item3'].map(str)
df['Item3'] = df['Item3'].astype(survey_rankings)
df['Item4'] = df['Item4'].map(str)
df['Item4'] = df['Item4'].astype(survey_rankings)
df['Item5'] = df['Item5'].map(str)
df['Item5'] = df['Item5'].astype(survey_rankings)
df['Item6'] = df['Item6'].map(str)
df['Item6'] = df['Item6'].astype(survey_rankings)
df['Item7'] = df['Item7'].map(str)
df['Item7'] = df['Item7'].astype(survey_rankings)
df['Item8'] = df['Item8'].map(str)
df['Item8'] = df['Item8'].astype(survey_rankings)

# %%
#Updating column names with python casing
new_names = {
    'CaseOrder': 'case_order',
    'Customer_id': 'customer_id',
    'Interaction': 'interaction',
    'UID': 'uid',
    'City': 'city',
    'State': 'state',
    'County': 'county',
    'Zip': 'zip_code',
    'Lat': 'latitude',
    'Lng': 'longitude',
    'Population': 'population',
    'Area': 'area_type',
    'Timezone': 'timezone',
    'Job': 'job_title',
    'Children': 'children',
    'Age': 'age',
    'Education': 'highest_education',
    'Employment': 'employment_status',
    'Income': 'income',
    'Marital': 'marital_status',
    'Gender': 'gender',
    'ReAdmis': 'readmission',
    'VitD_levels': 'vitamin_d_level',
    'Doc_visits': 'doctor_visits',
    'Full_meals_eaten': 'full_meals_eaten',
    'VitD_supp': 'vitamin_d_supplements',
    'Soft_drink': 'soft_drink',
    'Initial_admin': 'initial_admit_type',
    'HighBlood': 'high_bp',
    'Stroke': 'stroke',
    'Complication_risk': 'complication_risk',
    'Overweight': 'overweight',
    'Arthritis': 'arthritis',
    'Diabetes': 'diabetes',
    'Hyperlipidemia': 'hyperlipidemia',
    'BackPain': 'back_pain',
    'Anxiety': 'anxiety',
    'Allergic_rhinitis': 'allergic_rhinitis',
    'Reflux_esophagitis': 'reflux_esophagitis',
    'Asthma': 'asthma',
    'Services': 'services',
    'Initial_days': 'initial_stay',
    'TotalCharge': 'daily_charge',
    'Additional_charges': 'additional_charge',
    'Item1': 'srv1_timely_admission',
    'Item2': 'srv2_timely_treatment',
    'Item3': 'srv3_timely_visits',
    'Item4': 'srv4_reliability',
    'Item5': 'srv5_options',
    'Item6': 'srv6_treatment_hours',
    'Item7': 'srv7_courteous_staff',
    'Item8': 'srv8_doctor_listening'}
df.rename(columns=new_names, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10000 entries, 1 to 10000
# Data columns (total 52 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   case_order             10000 non-null  int64
#  1   customer_id            10000 non-null  object
#  2   interaction            10000 non-null  object
#  3   uid                    10000 non-null  object
#  4   city                   10000 non-null  object
#  5   state                  10000 non-null  object
#  6   county                 10000 non-null  object
#  7   zip_code               10000 non-null  object
#  8   latitude               10000 non-null  float64
#  9   longitude              10000 non-null  float64
#  10  population             10000 non-null  int64
#  11  area_type              10000 non-null  category
#  12  timezone               10000 non-null  category
#  13  job_title              10000 non-null  object
#  14  children               10000 non-null  int64
#  15  age                    10000 non-null  Int64
#  16  highest_education      10000 non-null  category
#  17  employment_status      10000 non-null  category
#  18  income                 10000 non-null  float64
#  19  marital_status         10000 non-null  category
#  20  gender                 10000 non-null  category
#  21  readmission            10000 non-null  bool
#  22  vitamin_d_level        10000 non-null  float64
#  23  doctor_visits          10000 non-null  int64
#  24  full_meals_eaten       10000 non-null  int64
#  25  vitamin_d_supplements  10000 non-null  int64
#  26  soft_drink             10000 non-null  bool
#  27  initial_admit_type     10000 non-null  category
#  28  high_bp                10000 non-null  bool
#  29  stroke                 10000 non-null  bool
#  30  complication_risk      10000 non-null  category
#  31  overweight             10000 non-null  bool
#  32  arthritis              10000 non-null  bool
#  33  diabetes               10000 non-null  bool
#  34  hyperlipidemia         10000 non-null  bool
#  35  back_pain              10000 non-null  bool
#  36  anxiety                10000 non-null  bool
#  37  allergic_rhinitis      10000 non-null  bool
#  38  reflux_esophagitis     10000 non-null  bool
#  39  asthma                 10000 non-null  bool
#  40  services               10000 non-null  category
#  41  initial_stay           10000 non-null  int64
#  42  daily_charge           10000 non-null  float64
#  43  additional_charge      10000 non-null  float64
#  44  srv1_timely_admission  10000 non-null  category
#  45  srv2_timely_treatment  10000 non-null  category
#  46  srv3_timely_visits     10000 non-null  category
#  47  srv4_reliability       10000 non-null  category
#  48  srv5_options           10000 non-null  category
#  49  srv6_treatment_hours   10000 non-null  category
#  50  srv7_courteous_staff   10000 non-null  category
#  51  srv8_doctor_listening  10000 non-null  category
# dtypes: Int64(1), bool(13), category(17), float64(6), int64(7), object(8)
# memory usage: 2.1+ MB

# %%
df.head(25)
# Out:
#     case_order customer_id                           interaction  \
# 1            1     C412403  8cd49b13-f45a-4b47-a2bd-173ffa932c2f
# 2            2     Z919181  d2450b70-0337-4406-bdbb-bc1037f1734c
# 3            3     F995323  a2057123-abf5-4a2c-abad-8ffe33512562
# 4            4     A879973  1dec528d-eb34-4079-adce-0d7a40e82205
# 5            5     C544523  5885f56b-d6da-43a3-8760-83583af94266
# 6            6     S543885  e3b0a319-9e2e-4a23-8752-2fdc736c30f4
# 7            7     E543302  2fccb53e-bd9a-4eaa-a53c-9dfc0cb83f94
# 8            8     K477307  ab634508-dd8c-42e5-a4e4-d101a46f2431
# 9            9     Q870521  67b386eb-1d04-4020-9474-542a09d304e3
# 10          10     Z229385  5acd5dd3-f0ae-41c7-9540-cf3e4ecb2e27
# 11          11     V593392  f79fac5c-6143-4333-91c1-da4d283db35f
# 12          12     X459469  cc050bb7-3b61-4934-b0fe-61bd0ec79dfd
# 13          13     N755131  103b3846-6933-452b-a66b-a59a18d29d57
# 14          14     D550524  542acef9-365b-4cf4-a92e-21bdf28830d4
# 15          15     T490287  19caf80a-cdc4-43a7-890d-72b07a62e5be
# 16          16     G169983  a38fe3ce-976a-478b-a014-33ac71f24ea9
# 17          17     O377757  7faf0261-bc66-489a-a8ba-fec333485254
# 18          18     I745784  c173d889-8d12-4375-819e-cd83902c9de8
# 19          19     D139360  9a1a84da-d99e-47f7-9865-1ef046db34d3
# 20          20     Y964627  e655e7c9-6d10-4817-bdb2-f3b34716d0e0
# 21          21     G754212  59bfca8f-18ae-4a81-a531-6597ab6d6352
# 22          22      J10137  abd4baf3-c937-4353-af45-75d119579c04
# 23          23     S147737  7b553658-a4e2-48f0-a81b-d70d2c1b6c02
# 24          24     Y454618  cbe8390d-84d6-4cd9-b25d-bf1a154235c8
# 25          25     Y563432  ca1e9204-516e-4145-869c-fdc66a5e3063
#
#                                  uid           city state        county  \
# 1   3a83ddb66e2ae73798bdf1d705dc0932            Eva    AL        Morgan
# 2   176354c5eef714957d486009feabf195       Marianna    FL       Jackson
# 3   e19a0fa00aeda885b8a436757e889bc9    Sioux Falls    SD     Minnehaha
# 4   cd17d7b6d152cb6f23957346d11c3f07   New Richland    MN        Waseca
# 5   d2f0425877b10ed6bb381f3e2579424a     West Point    VA  King William
# 6   03e447146d4a32e1aaf75727c3d1230c         Braggs    OK      Muskogee
# 7   e4884a42ba809df6a89ded6c97f460d4       Thompson    OH        Geauga
# 8   5f78b8699d1aa9b950b562073f629ca2      Strasburg    VA    Shenandoah
# 9   e8e016144bfbe14974752d834f530e26    Panama City    FL           Bay
# 10  687e7ba1b80022c310fa2d4b00db199a    Paynesville    MN       Stearns
# 11  4c2b0a61d8352835b59d74fc46a11b71      Daleville    MS    Lauderdale
# 12  5e1aa1c71a30c77a542c68452793b986    Casselberry    FL      Seminole
# 13  e2b9d07fa9d57d7e411299f47abcc505  Saint Francis    WI     Milwaukee
# 14  11242d7514ece3946f167db79410254b        Denison    IA      Crawford
# 15  fa79d3f149c5ff752044070cb272ef15   Sioux Center    IA         Sioux
# 16  8e866e2402ea8db6d0584209f714ee2d     Huntsville    AL       Madison
# 17  728333940561457a9feba1e1dc763258         Blythe    CA     Riverside
# 18  a8437eadfb17988b7d7fedcc0468664e       Matthews    IN         Grant
# 19  0bcee05e1fc26d492f0559675ab318b0         Lignum    VA      Culpeper
# 20  7dd9f4cf50d66af07b37fa8951957d72           Mora    MO        Pettis
# 21  d49dab16a42bad5d54e2691b1b021f94     Saint Paul    MN        Ramsey
# 22  77c1f9fa56ab519aa9fe456d365e7174         Maybee    MI        Monroe
# 23  34898a0f4109efc1b2415ca01ce450de    Big Springs    NE         Deuel
# 24  bf6eb8bbc86ade8a382121b6e07944ed         Quapaw    OK        Ottawa
# 25  2eeedddcddd8e1eaa9d137babc330b4f    Campbellton    FL       Jackson
#
#    zip_code  latitude  longitude  population area_type timezone  \
# 1     35621  34.34960  -86.72508        2951  Suburban    US/CT
# 2     32446  30.84513  -85.22907       11303     Urban    US/CT
# 3     57110  43.54321  -96.63772       17125  Suburban    US/CT
# 4     56072  43.89744  -93.51479        2162  Suburban    US/CT
# 5     23181  37.59894  -76.88958        5287     Rural    US/ET
# 6     74423  35.67302  -95.19180         981     Urban    US/CT
# 7     44086  41.67511  -81.05788        2558     Rural    US/ET
# 8     22641  39.08062  -78.39150         479     Urban    US/ET
# 9     32404  30.20097  -85.50610       40029     Urban    US/CT
# 10    56362  45.40325  -94.71424        5840     Urban    US/CT
# 11    39326  32.59914  -88.67903         426     Urban    US/CT
# 12    32707  28.66268  -81.31427       35369  Suburban    US/ET
# 13    53235  42.97168  -87.87294        9477     Urban    US/CT
# 14    51442  42.03038  -95.35836        9793  Suburban    US/CT
# 15    51250  43.08426  -96.21239        8565  Suburban    US/CT
# 16    35811  34.79693  -86.50603       27658     Urban    US/CT
# 17    92225  33.74647 -114.66793       22149  Suburban    US/PT
# 18    46957  40.38836  -85.49633         612  Suburban    US/ET
# 19    22726  38.40136  -77.82225         744     Rural    US/ET
# 20    65345  38.54040  -93.13023         281     Urban    US/CT
# 21    55103  44.96425  -93.12449       13947  Suburban    US/CT
# 22    48159  42.02415  -83.55359        2574     Urban    US/ET
# 23    69122  41.13007 -102.10258         729     Urban    US/MT
# 24    74363  36.95315  -94.71438        2879     Rural    US/CT
# 25    32426  30.94714  -85.36944         914     Rural    US/CT
#
#                                job_title  children  age  \
# 1       Psychologist, sport and exercise         1   53
# 2           Community development worker         3   51
# 3                Chief Executive Officer         3   53
# 4                    Early years teacher         0   78
# 5            Health promotion specialist         0   22
# 6                    Corporate treasurer         0   76
# 7                            Hydrologist         0   50
# 8                      Psychiatric nurse         7   40
# 9               Computer games developer         0   48
# 10           Production assistant, radio         2   78
# 11                            Contractor         4   55
# 12                   Early years teacher         0   64
# 13    Surveyor, planning and development         0   41
# 14  English as a second language teacher         0   45
# 15                               Actuary         1   85
# 16                         Media planner         0   53
# 17          Fast food restaurant manager        10   44
# 18            Horticulturist, commercial         0   54
# 19                    Secretary, company         1   72
# 20                     Designer, graphic         0   84
# 21                     Personnel officer         2   53
# 22         Telecommunications researcher         4   52
# 23         Restaurant manager, fast food         0   31
# 24                    Surveyor, minerals         3   53
# 25            Architectural technologist         0   53
#
#                            highest_education employment_status     income  \
# 1             Some College, Less than 1 Year         Full Time   86575.93
# 2   Some College, 1 or More Years, No Degree         Full Time   46805.99
# 3   Some College, 1 or More Years, No Degree           Retired   14370.14
# 4              GED or Alternative Credential           Retired   39741.49
# 5                Regular High School Diploma         Full Time    1209.56
# 6                Regular High School Diploma           Retired   33942.00
# 7                          Bachelor's Degree           Retired   10456.05
# 8                            Master's Degree         Full Time   33942.00
# 9                Regular High School Diploma         Full Time   55586.48
# 10  Some College, 1 or More Years, No Degree         Full Time   38965.22
# 11                           Master's Degree         Full Time   38503.82
# 12               Nursery School to 8th Grade        Unemployed   14126.30
# 13       9th Grade to 12th Grade, No Diploma        Unemployed   33942.00
# 14               Regular High School Diploma         Full Time   33942.00
# 15                          Doctorate Degree           Student   41558.19
# 16                         Bachelor's Degree           Student  103866.49
# 17  Some College, 1 or More Years, No Degree         Full Time   24250.51
# 18               Regular High School Diploma         Part Time   17345.63
# 19                        Associate's Degree         Full Time   61723.87
# 20               Regular High School Diploma         Full Time   62054.63
# 21               Regular High School Diploma         Part Time    8686.47
# 22       9th Grade to 12th Grade, No Diploma         Full Time   10279.73
# 23                Professional School Degree         Full Time   57621.66
# 24               Regular High School Diploma           Retired   32677.97
# 25                        Associate's Degree         Full Time   14925.43
#
#    marital_status      gender  readmission  vitamin_d_level  doctor_visits  \
# 1        Divorced        Male         True        17.802330              6
# 2         Married      Female         True        18.994640              4
# 3         Widowed      Female         True        17.415889              4
# 4         Married        Male         True        17.420079              4
# 5         Widowed      Female         True        16.870524              5
# 6   Never Married        Male         True        19.956143              6
# 7   Never Married        Male         True        14.348350              6
# 8        Divorced      Female         True        20.425926              7
# 9         Widowed        Male         True        19.539212              6
# 10  Never Married      Female         True        19.628554              7
# 11        Married      Female         True        17.613389              6
# 12       Divorced        Male         True        47.813476              7
# 13        Widowed      Female         True        16.492398              5
# 14       Divorced        Male         True        14.791835              5
# 15       Divorced      Female         True        15.982161              4
# 16       Divorced      Female         True        15.270191              4
# 17       Divorced        Male         True        17.163216              5
# 18  Never Married      Female         True        17.286029              4
# 19        Widowed      Female         True        18.827262              7
# 20      Separated  Non-Binary         True        17.299816              6
# 21       Divorced      Female         True        19.968337              6
# 22      Separated        Male         True        16.512633              6
# 23        Widowed      Female         True        25.514635              5
# 24      Separated        Male         True        16.494546              6
# 25        Married      Female         True        15.526456              5
#
#     full_meals_eaten  vitamin_d_supplements  soft_drink  \
# 1                  0                      0        True
# 2                  2                      1        True
# 3                  1                      0        True
# 4                  1                      0        True
# 5                  0                      2        True
# 6                  0                      0        True
# 7                  0                      0        True
# 8                  2                      0        True
# 9                  3                      0        True
# 10                 1                      2        True
# 11                 3                      0        True
# 12                 3                      0        True
# 13                 3                      1        True
# 14                 0                      0        True
# 15                 2                      1        True
# 16                 1                      0        True
# 17                 1                      1        True
# 18                 2                      0        True
# 19                 2                      1        True
# 20                 1                      2        True
# 21                 2                      2        True
# 22                 1                      0        True
# 23                 0                      2        True
# 24                 1                      0        True
# 25                 1                      0        True
#
#        initial_admit_type  high_bp  stroke complication_risk  overweight  \
# 1     Emergency Admission     True    True            Medium       False
# 2     Emergency Admission     True    True              High        True
# 3      Elective Admission     True    True            Medium        True
# 4      Elective Admission     True    True            Medium       False
# 5      Elective Admission     True    True               Low       False
# 6   Observation Admission     True    True            Medium        True
# 7     Emergency Admission     True    True               Low        True
# 8   Observation Admission     True    True            Medium        True
# 9     Emergency Admission     True    True               Low        True
# 10    Emergency Admission     True    True              High        True
# 11    Emergency Admission     True    True            Medium        True
# 12     Elective Admission     True    True              High        True
# 13    Emergency Admission     True    True            Medium        True
# 14    Emergency Admission     True    True              High       False
# 15    Emergency Admission     True    True            Medium       False
# 16  Observation Admission     True    True               Low        True
# 17    Emergency Admission     True    True            Medium        True
# 18  Observation Admission     True    True              High        True
# 19     Elective Admission     True    True            Medium       False
# 20    Emergency Admission     True    True               Low        True
# 21    Emergency Admission     True    True              High        True
# 22    Emergency Admission     True    True               Low       False
# 23    Emergency Admission     True    True              High       False
# 24    Emergency Admission     True    True            Medium        True
# 25    Emergency Admission     True    True               Low       False
#
#     arthritis  diabetes  hyperlipidemia  back_pain  anxiety  \
# 1        True      True            True       True     True
# 2        True      True            True       True    False
# 3        True      True            True       True    False
# 4        True      True            True       True    False
# 5        True      True            True       True    False
# 6        True      True            True       True    False
# 7        True      True            True       True     True
# 8        True      True            True       True    False
# 9        True      True            True       True    False
# 10       True      True            True       True    False
# 11       True      True            True       True    False
# 12       True      True            True       True    False
# 13       True      True            True       True     True
# 14       True      True            True       True     True
# 15       True      True            True       True     True
# 16       True      True            True       True    False
# 17       True      True            True       True    False
# 18       True      True            True       True    False
# 19       True      True            True       True    False
# 20       True      True            True       True     True
# 21       True      True            True       True    False
# 22       True      True            True       True     True
# 23       True      True            True       True    False
# 24       True      True            True       True    False
# 25       True      True            True       True     True
#
#     allergic_rhinitis  reflux_esophagitis  asthma     services  initial_stay  \
# 1                True                True    True   Blood Work            10
# 2                True                True    True  Intravenous            15
# 3                True                True    True   Blood Work             4
# 4                True                True    True   Blood Work             1
# 5                True                True    True      CT Scan             1
# 6                True                True    True   Blood Work             5
# 7                True                True    True  Intravenous             9
# 8                True                True    True  Intravenous             0
# 9                True                True    True  Intravenous             6
# 10               True                True    True   Blood Work             1
# 11               True                True    True  Intravenous             2
# 12               True                True    True      CT Scan             7
# 13               True                True    True      CT Scan             3
# 14               True                True    True  Intravenous             2
# 15               True                True    True  Intravenous             1
# 16               True                True    True      CT Scan             2
# 17               True                True    True  Intravenous             7
# 18               True                True    True  Intravenous             2
# 19               True                True    True  Intravenous             7
# 20               True                True    True   Blood Work            10
# 21               True                True    True   Blood Work             7
# 22               True                True    True  Intravenous             5
# 23               True                True    True  Intravenous             3
# 24               True                True    True   Blood Work            11
# 25               True                True    True   Blood Work            18
#
#     daily_charge  additional_charge srv1_timely_admission  \
# 1        3191.05           17939.40                     3
# 2        4214.91           17613.00                     3
# 3        2177.59           17505.19                     2
# 4        2465.12           12993.44                     3
# 5        1885.66            3716.53                     2
# 6        2774.09           12742.59                     4
# 7        3533.29           16815.51                     4
# 8        3316.40            6930.57                     1
# 9        2922.76            8363.19                     3
# 10       3709.55           26225.99                     5
# 11       3042.39           18518.04                     3
# 12      14804.32           21480.89                     4
# 13       2622.02            7357.83                     4
# 14       1919.15            8454.61                     3
# 15       2330.42           14382.23                     4
# 16       2228.68            9415.37                     4
# 17       2938.95            8157.75                     5
# 18       2631.70            9539.22                     4
# 19       2990.09           23453.36                     3
# 20       4026.97           14051.44                     2
# 21       3772.16           28788.08                     3
# 22       3252.27            9128.65                     4
# 23       3810.39           11112.14                     4
# 24       3532.60           12876.79                     4
# 25       3971.11            3624.05                     4
#
#    srv2_timely_treatment srv3_timely_visits srv4_reliability srv5_options  \
# 1                      3                  2                2            4
# 2                      4                  3                4            4
# 3                      4                  4                4            3
# 4                      5                  5                3            4
# 5                      1                  3                3            5
# 6                      5                  4                4            3
# 7                      3                  3                2            3
# 8                      2                  2                5            4
# 9                      3                  2                3            3
# 10                     5                  5                3            4
# 11                     3                  4                4            2
# 12                     5                  5                5            3
# 13                     4                  2                4            5
# 14                     3                  3                5            4
# 15                     5                  5                4            5
# 16                     5                  4                4            4
# 17                     4                  5                2            4
# 18                     4                  3                5            2
# 19                     4                  4                3            4
# 20                     2                  2                4            4
# 21                     3                  4                4            3
# 22                     4                  4                3            3
# 23                     5                  5                3            5
# 24                     4                  3                4            2
# 25                     3                  4                4            3
#
#    srv6_treatment_hours srv7_courteous_staff srv8_doctor_listening
# 1                     3                    3                     4
# 2                     4                    3                     3
# 3                     4                    3                     3
# 4                     5                    5                     5
# 5                     3                    4                     3
# 6                     5                    4                     6
# 7                     4                    5                     5
# 8                     2                    4                     2
# 9                     3                    4                     2
# 10                    2                    3                     2
# 11                    5                    2                     3
# 12                    3                    3                     3
# 13                    2                    4                     3
# 14                    5                    3                     2
# 15                    3                    3                     5
# 16                    3                    3                     3
# 17                    3                    4                     3
# 18                    4                    5                     4
# 19                    2                    3                     2
# 20                    3                    5                     1
# 21                    3                    3                     1
# 22                    4                    4                     4
# 23                    6                    3                     5
# 24                    3                    6                     4
# 25                    4                    2                     2

# %% [markdown]
# ## D5 Data CSV

# %%
#Saving the cleaned data in a CSV file
df.to_csv('clean_data.csv', index=False)

# %% [markdown]
# ## E1 PCA

# %%
#Storing numeric variables in a new data frame to use for PCA
medical = df[['latitude', 'longitude', 'population', 'children', 'age', 'income', 'vitamin_d_level', 'doctor_visits', 'full_meals_eaten', 'vitamin_d_supplements', 'initial_stay', 'daily_charge', 'additional_charge']]
#Normalizing the data before calling the PCA
medical_normalized = (medical-medical.mean())/medical.std()
#Setting the amount of components I want from the analysis
pca = PCA(n_components=medical.shape[1])
#Fitting normalized data
pca.fit(medical_normalized)
#Creating a new dataset for the PCA to convert and load components for each variable
medical_pca = pd.DataFrame(pca.transform(medical_normalized), columns=['PC1', 'PC2', 'PC3', 'PC4', 'PC5', 'PC6', 'PC7', 'PC8', 'PC9', 'PC10', 'PC11', 'PC12', 'PC13'])
medical_loadings = pd.DataFrame(pca.components_.T, columns=['PC1', 'PC2', 'PC3', 'PC4', 'PC5', 'PC6', 'PC7', 'PC8', 'PC9', 'PC10', 'PC11', 'PC12', 'PC13'], index=medical_normalized.columns)
medical_loadings
# Out:
#                             PC1       PC2       PC3       PC4       PC5  \
# latitude              -0.019982 -0.008145 -0.715228  0.127639 -0.045051
# longitude             -0.003419  0.016842  0.270110 -0.630585 -0.209971
# population             0.022666 -0.024893  0.631223  0.299474  0.122230
# children              -0.000770  0.011103  0.015434  0.237951  0.100231
# age                    0.094387  0.699653  0.006920  0.006639 -0.028994
# income                -0.007726 -0.004840  0.045269  0.258038  0.411356
# vitamin_d_level        0.558046 -0.066828 -0.044486 -0.197506  0.366882
# doctor_visits         -0.006497  0.013141  0.014009  0.204519  0.413239
# full_meals_eaten      -0.005481  0.035309 -0.103721 -0.267278  0.446555
# vitamin_d_supplements  0.033177  0.010290  0.031077  0.406589 -0.187479
# initial_stay           0.419824 -0.075432  0.020984  0.233780 -0.467820
# daily_charge           0.701532 -0.090534 -0.019297 -0.012801  0.006982
# additional_charge      0.095483  0.699637  0.000809  0.027041 -0.002904
#
#                             PC6       PC7       PC8       PC9      PC10  \
# latitude              -0.035083 -0.026860 -0.066751 -0.006144 -0.041580
# longitude             -0.450317  0.299904 -0.002067 -0.167276  0.129056
# population             0.255101 -0.196929 -0.053961  0.092745 -0.021094
# children               0.271479  0.841868 -0.345998 -0.122335  0.125514
# age                    0.002557 -0.013319  0.000272 -0.007955 -0.028385
# income                -0.370044  0.278150  0.582622 -0.150237 -0.428287
# vitamin_d_level       -0.072761  0.023314 -0.202413  0.364145 -0.105013
# doctor_visits         -0.419841 -0.267797 -0.429850 -0.511508  0.298812
# full_meals_eaten       0.362680 -0.006290  0.459441 -0.084658  0.601846
# vitamin_d_supplements -0.443735  0.106236  0.155358  0.512935  0.549092
# initial_stay           0.100817 -0.024450  0.269250 -0.510815  0.128655
# daily_charge           0.000534  0.002589 -0.001841 -0.018306 -0.009547
# additional_charge      0.010179 -0.008945 -0.001338 -0.000213 -0.022367
#
#                            PC11      PC12      PC13
# latitude               0.679158 -0.014990  0.002623
# longitude              0.384132  0.009592  0.000451
# population             0.616234 -0.015463 -0.000432
# children              -0.002029 -0.009498  0.000552
# age                   -0.002557 -0.706596  0.017530
# income                 0.047582 -0.007463  0.000288
# vitamin_d_level        0.006013 -0.023635 -0.563467
# doctor_visits         -0.057282 -0.005449 -0.000810
# full_meals_eaten       0.070382 -0.009364  0.005148
# vitamin_d_supplements -0.020323 -0.004878 -0.000375
# initial_stay          -0.005944 -0.006101 -0.428129
# daily_charge          -0.000950  0.021526  0.705812
# additional_charge      0.021136  0.706272 -0.026419

# %% [markdown]
# ## E2 PCA Criteria

# %%
covar_matrix = np.dot(medical_normalized.T, medical_normalized) / medical.shape[0]
eigenvalues = [np.dot(eigenvector.T, np.dot(covar_matrix, eigenvector)) for
eigenvector in pca.components_]

plt.plot(eigenvalues)
plt.title('PCA Scree Plot ft. Eigenvalues')
plt.xlabel('Component #')
plt.ylabel('Eigenvalues')
plt.axhline(y=1, color='green')
plt.show()

# %%
eigenvalues
# Out:
# [1.9175825461780955,
#  1.6179608044482654,
#  1.226471579650826,
#  1.0410534860157434,
#  1.0267589532391135,
#  1.0213163215236964,
#  0.997066548826096,
#  0.9869115577227542,
#  0.9834021625261434,
#  0.9718637621411118,
#  0.7466640790014459,
#  0.3780962572301816,
#  0.08355194149629128]
